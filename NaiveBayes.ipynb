# %% [markdown]
# <a href="https://colab.research.google.com/github/spooki-chan/CS-31_SDGP/blob/sub/NaiveBayes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("newfood.csv")

# %%
df
# Out:
#         id                                             title  pricePerServing  \
# 0        1                         Fried Anchovies with Sage           5.6051
# 1        2  Anchovies Appetizer With Breadcrumbs & Scallions           0.8206
# 2        3                Carrots, Cauliflower And Anchovies           4.3800
# 3        4  Bap Story Stir Fried Anchovies (Myulchi Bokkeum)           8.1122
# 4        5                       Bread, Butter And Anchovies           0.2557
# ...    ...                                               ...              ...
# 1717  1995                          Blackened Salmon Fillets           4.4589
# 1718  1996                       Vegetable Stew With Halibut           0.1400
# 1719  1997                 Snapper Tacos with Chipotle Cream           2.8066
# 1720  1998                  Smoky Maple-glazed Salmon Supper           6.8995
# 1721  1999                              spicy tomato mussels           0.3231
#
#       weightPerServing  vegetarian  vegan  glutenFree  dairyFree  sustainable  \
# 0                  226       False  False       False       True        False
# 1                   33       False  False       False       True        False
# 2                  364       False  False       False       True        False
# 3                  711       False  False        True       True        False
# 4                   36       False  False       False      False        False
# ...                ...         ...    ...         ...        ...          ...
# 1717               209       False  False        True      False        False
# 1718                32       False  False        True      False        False
# 1719               333       False  False       False      False        False
# 1720               474       False  False        True      False        False
# 1721                55       False  False        True       True        False
#
#       veryHealthy  ...  Vitamin D/µg Vitamin K/µg  Vitamin C/mg  Alcohol/g  \
# 0           False  ...          0.29         0.00          0.00        0.0
# 1           False  ...          0.00         7.18          0.00        0.0
# 2            True  ...          0.00       104.27         32.60        0.0
# 3            True  ...          6.24        16.02          3.88        0.0
# 4           False  ...          0.00         2.21          0.00        0.0
# ...           ...  ...           ...          ...           ...        ...
# 1717        False  ...          0.43         9.61          1.43        0.0
# 1718        False  ...          0.00         2.26          3.47        0.0
# 1719        False  ...         11.79         8.64         17.63        0.0
# 1720         True  ...          0.00        44.11         34.17        0.0
# 1721        False  ...          0.00         2.86         12.65        0.0
#
#       Caffeine/g  stars  popularity userId  tfdbId  recipeId
# 0            0.0      3  150.437577      1       1      1915
# 1            0.0      1  139.082615      1       2      1916
# 2            0.0      4  107.376788      1       3      1918
# 3            0.0      3  112.312950      1       4      1919
# 4            0.0      5   43.926995      1       5      1920
# ...          ...    ...         ...    ...     ...       ...
# 1717         0.0      3   37.729059     14    1995      1480
# 1718         0.0      4   18.650748     14    1996      1481
# 1719         0.0      3   15.794946     14    1997      1482
# 1720         0.0      4   45.054936     14    1998      1483
# 1721         0.0      5   25.039383     14    1999      1484
#
# [1722 rows x 63 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1722 entries, 0 to 1721
# Data columns (total 63 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    1722 non-null   int64
#  1   title                 1722 non-null   object
#  2   pricePerServing       1722 non-null   float64
#  3   weightPerServing      1722 non-null   int64
#  4   vegetarian            1722 non-null   bool
#  5   vegan                 1722 non-null   bool
#  6   glutenFree            1722 non-null   bool
#  7   dairyFree             1722 non-null   bool
#  8   sustainable           1722 non-null   bool
#  9   veryHealthy           1722 non-null   bool
#  10  veryPopular           1722 non-null   bool
#  11  gaps                  1722 non-null   object
#  12  lowFodmap             1722 non-null   bool
#  13  ketogenic             1722 non-null   bool
#  14  whole30               1722 non-null   bool
#  15  readyInMinutes        1722 non-null   int64
#  16  spoonacularSourceUrl  1722 non-null   object
#  17  image                 1718 non-null   object
#  18  aggregateLikes        1722 non-null   int64
#  19  spoonacularScore      1722 non-null   int64
#  20  healthScore           1722 non-null   int64
#  21  percentProtein        1722 non-null   float64
#  22  percentFat            1722 non-null   float64
#  23  percentCarbs          1722 non-null   float64
#  24  dishTypes             1722 non-null   object
#  25  ingredients           1722 non-null   object
#  26  calories              1722 non-null   float64
#  27  Fat/g                 1722 non-null   float64
#  28  Saturated Fat/g       1722 non-null   float64
#  29  Carbohydrates/g       1722 non-null   float64
#  30  Sugar/g               1722 non-null   float64
#  31  Cholesterol/mg        1722 non-null   float64
#  32  Sodium/mg             1722 non-null   float64
#  33  Protein/g             1722 non-null   float64
#  34  Vitamin B3/mg         1722 non-null   float64
#  35  Selenium/µg           1722 non-null   float64
#  36  Phosphorus/mg         1722 non-null   float64
#  37  Iron/mg               1722 non-null   float64
#  38  Vitamin B2/mg         1722 non-null   float64
#  39  Calcium/mg            1722 non-null   float64
#  40  Vitamin B1/mg         1722 non-null   float64
#  41  Folate/µg             1722 non-null   float64
#  42  Potassium/mg          1722 non-null   float64
#  43  Copper/mg             1722 non-null   float64
#  44  Zinc/mg               1722 non-null   float64
#  45  Manganese/mg          1722 non-null   float64
#  46  Magnesium/mg          1722 non-null   float64
#  47  Vitamin B12/µg        1722 non-null   float64
#  48  Vitamin B5/mg         1722 non-null   float64
#  49  Vitamin B6/mg         1722 non-null   float64
#  50  Vitamin E/mg          1722 non-null   float64
#  51  Fiber/g               1722 non-null   float64
#  52  Vitamin A/IU          1722 non-null   float64
#  53  Vitamin D/µg          1722 non-null   float64
#  54  Vitamin K/µg          1722 non-null   float64
#  55  Vitamin C/mg          1722 non-null   float64
#  56  Alcohol/g             1722 non-null   float64
#  57  Caffeine/g            1722 non-null   float64
#  58  stars                 1722 non-null   int64
#  59  popularity            1722 non-null   float64
#  60  userId                1722 non-null   int64
#  61  tfdbId                1722 non-null   int64
#  62  recipeId              1722 non-null   int64
# dtypes: bool(10), float64(37), int64(10), object(6)
# memory usage: 730.0+ KB

# %%
df.head()
# Out:
#    id                                             title  pricePerServing  \
# 0   1                         Fried Anchovies with Sage           5.6051
# 1   2  Anchovies Appetizer With Breadcrumbs & Scallions           0.8206
# 2   3                Carrots, Cauliflower And Anchovies           4.3800
# 3   4  Bap Story Stir Fried Anchovies (Myulchi Bokkeum)           8.1122
# 4   5                       Bread, Butter And Anchovies           0.2557
#
#    weightPerServing  vegetarian  vegan  glutenFree  dairyFree  sustainable  \
# 0               226       False  False       False       True        False
# 1                33       False  False       False       True        False
# 2               364       False  False       False       True        False
# 3               711       False  False        True       True        False
# 4                36       False  False       False      False        False
#
#    veryHealthy  ...  Vitamin D/µg Vitamin K/µg  Vitamin C/mg  Alcohol/g  \
# 0        False  ...          0.29         0.00          0.00        0.0
# 1        False  ...          0.00         7.18          0.00        0.0
# 2         True  ...          0.00       104.27         32.60        0.0
# 3         True  ...          6.24        16.02          3.88        0.0
# 4        False  ...          0.00         2.21          0.00        0.0
#
#    Caffeine/g  stars  popularity userId  tfdbId  recipeId
# 0         0.0      3  150.437577      1       1      1915
# 1         0.0      1  139.082615      1       2      1916
# 2         0.0      4  107.376788      1       3      1918
# 3         0.0      3  112.312950      1       4      1919
# 4         0.0      5   43.926995      1       5      1920
#
# [5 rows x 63 columns]

# %%
df.drop(labels=['vegetarian','vegan', 'glutenFree', 'dairyFree', 'sustainable'],axis=1, inplace=True)

# %%
df.drop(labels=['weightPerServing','pricePerServing', 'gaps', 'lowFodmap', 'ketogenic'],axis=1, inplace=True)

# %%
df.drop(labels=['whole30','aggregateLikes', 'spoonacularScore', 'Vitamin B5/mg', 'Vitamin B6/mg'],axis=1, inplace=True)

# %%
df.drop(labels=['healthScore','percentProtein', 'percentFat', 'Magnesium/mg', 'Vitamin B12/µg'],axis=1, inplace=True)

# %%
df.drop(labels=['percentCarbs','Zinc/mg', 'Manganese/mg', 'Fiber/g', 'Vitamin E/mg'],axis=1, inplace=True)

# %%
df.drop(labels=['Fat/g','Saturated Fat/g', 'Carbohydrates/g', 'Sugar/g', 'Cholesterol/mg','Sodium/mg','Protein/g','Vitamin B3/mg','Selenium/µg','Phosphorus/mg','Iron/mg','Vitamin B2/mg','Calcium/mg','Vitamin C/mg','Alcohol/g','Caffeine/g'],axis=1, inplace=True)

# %%
df
# Out:
#         id                                             title  veryHealthy  \
# 0        1                         Fried Anchovies with Sage        False
# 1        2  Anchovies Appetizer With Breadcrumbs & Scallions        False
# 2        3                Carrots, Cauliflower And Anchovies         True
# 3        4  Bap Story Stir Fried Anchovies (Myulchi Bokkeum)         True
# 4        5                       Bread, Butter And Anchovies        False
# ...    ...                                               ...          ...
# 1717  1995                          Blackened Salmon Fillets        False
# 1718  1996                       Vegetable Stew With Halibut        False
# 1719  1997                 Snapper Tacos with Chipotle Cream        False
# 1720  1998                  Smoky Maple-glazed Salmon Supper         True
# 1721  1999                              spicy tomato mussels        False
#
#       veryPopular  readyInMinutes  \
# 0           False              45
# 1           False              15
# 2           False              45
# 3           False              45
# 4           False               3
# ...           ...             ...
# 1717        False              25
# 1718        False              37
# 1719        False              45
# 1720        False              45
# 1721        False              45
#
#                                    spoonacularSourceUrl  \
# 0     https://spoonacular.com/fried-anchovies-with-s...
# 1     https://spoonacular.com/anchovies-appetizer-wi...
# 2     https://spoonacular.com/carrots-cauliflower-an...
# 3     https://spoonacular.com/bap-story-stir-fried-a...
# 4     https://spoonacular.com/bread-butter-and-ancho...
# ...                                                 ...
# 1717  https://spoonacular.com/blackened-salmon-fille...
# 1718  https://spoonacular.com/vegetable-stew-with-ha...
# 1719  https://spoonacular.com/snapper-tacos-with-chi...
# 1720  https://spoonacular.com/smoky-maple-glazed-sal...
# 1721  https://spoonacular.com/spicy-tomato-mussels-1999
#
#                                                   image dishTypes  \
# 0     https://spoonacular.com/recipeImages/1-556x370...  Maindish
# 1     https://spoonacular.com/recipeImages/2-556x370...   Starter
# 2     https://spoonacular.com/recipeImages/3-556x370...  Maindish
# 3     https://spoonacular.com/recipeImages/4-556x370...  Maindish
# 4     https://spoonacular.com/recipeImages/5-556x370...  Maindish
# ...                                                 ...       ...
# 1717  https://spoonacular.com/recipeImages/1995-556x...  Maindish
# 1718  https://spoonacular.com/recipeImages/1996-556x...   Starter
# 1719  https://spoonacular.com/recipeImages/1997-556x...  Maindish
# 1720  https://spoonacular.com/recipeImages/1998-556x...  Maindish
# 1721  https://spoonacular.com/recipeImages/127-556x3...   Starter
#
#                                             ingredients  calories  ...  \
# 0     anchovies,baking powder,egg,flour,sage leaves,...    384.09  ...
# 1      anchovies,bread,garlic clove,olive oil,scallions     57.07  ...
# 2     acini di pepe,almonds,anchovies,carrots,caulif...    942.08  ...
# 3     anchovies,baby-back ribs,cooking oil,frying oi...   1697.23  ...
# 4         bread,capers,salted anchovies,unsalted butter    112.75  ...
# ...                                                 ...       ...  ...
# 1717  dried basil,dried thyme,ground cayenne pepper,...    466.57  ...
# 1718  cherry tomatoes,chicken broth,fresh corn kerne...     24.02  ...
# 1719  butter,chipotle chile in adobo,flour tortillas...    418.20  ...
# 1720  brown rice,butter,carrots,chives,cider vinegar...    803.88  ...
# 1721  cherry tomatoes,chillies,coconut,coconut,cocon...     77.49  ...
#
#       Potassium/mg  Copper/mg  Vitamin A/IU  Vitamin D/µg  Vitamin K/µg  \
# 0           778.81       0.43        154.80          0.29          0.00
# 1           103.37       0.06          0.00          0.00          7.18
# 2           848.60       0.41      21572.42          0.00        104.27
# 3          1875.89       1.22        180.52          6.24         16.02
# 4            52.96       0.05        128.27          0.00          2.21
# ...            ...        ...           ...           ...           ...
# 1717        972.64       0.48       3028.81          0.43          9.61
# 1718         83.39       0.02         56.29          0.00          2.26
# 1719        846.11       0.17       1159.98         11.79          8.64
# 1720       1722.77       0.87      11146.08          0.00         44.11
# 1721        130.20       0.09        138.93          0.00          2.86
#
#       stars  popularity  userId  tfdbId  recipeId
# 0         3  150.437577       1       1      1915
# 1         1  139.082615       1       2      1916
# 2         4  107.376788       1       3      1918
# 3         3  112.312950       1       4      1919
# 4         5   43.926995       1       5      1920
# ...     ...         ...     ...     ...       ...
# 1717      3   37.729059      14    1995      1480
# 1718      4   18.650748      14    1996      1481
# 1719      3   15.794946      14    1997      1482
# 1720      4   45.054936      14    1998      1483
# 1721      5   25.039383      14    1999      1484
#
# [1722 rows x 22 columns]

# %%
df.drop(labels=['Vitamin B1/mg', 'Folate/µg', 'Potassium/mg', 'Copper/mg','Vitamin A/IU','Vitamin D/µg','Vitamin K/µg'],axis=1, inplace=True)

# %%
df
# Out:
#         id                                             title  veryHealthy  \
# 0        1                         Fried Anchovies with Sage        False
# 1        2  Anchovies Appetizer With Breadcrumbs & Scallions        False
# 2        3                Carrots, Cauliflower And Anchovies         True
# 3        4  Bap Story Stir Fried Anchovies (Myulchi Bokkeum)         True
# 4        5                       Bread, Butter And Anchovies        False
# ...    ...                                               ...          ...
# 1717  1995                          Blackened Salmon Fillets        False
# 1718  1996                       Vegetable Stew With Halibut        False
# 1719  1997                 Snapper Tacos with Chipotle Cream        False
# 1720  1998                  Smoky Maple-glazed Salmon Supper         True
# 1721  1999                              spicy tomato mussels        False
#
#       veryPopular  readyInMinutes  \
# 0           False              45
# 1           False              15
# 2           False              45
# 3           False              45
# 4           False               3
# ...           ...             ...
# 1717        False              25
# 1718        False              37
# 1719        False              45
# 1720        False              45
# 1721        False              45
#
#                                    spoonacularSourceUrl  \
# 0     https://spoonacular.com/fried-anchovies-with-s...
# 1     https://spoonacular.com/anchovies-appetizer-wi...
# 2     https://spoonacular.com/carrots-cauliflower-an...
# 3     https://spoonacular.com/bap-story-stir-fried-a...
# 4     https://spoonacular.com/bread-butter-and-ancho...
# ...                                                 ...
# 1717  https://spoonacular.com/blackened-salmon-fille...
# 1718  https://spoonacular.com/vegetable-stew-with-ha...
# 1719  https://spoonacular.com/snapper-tacos-with-chi...
# 1720  https://spoonacular.com/smoky-maple-glazed-sal...
# 1721  https://spoonacular.com/spicy-tomato-mussels-1999
#
#                                                   image dishTypes  \
# 0     https://spoonacular.com/recipeImages/1-556x370...  Maindish
# 1     https://spoonacular.com/recipeImages/2-556x370...   Starter
# 2     https://spoonacular.com/recipeImages/3-556x370...  Maindish
# 3     https://spoonacular.com/recipeImages/4-556x370...  Maindish
# 4     https://spoonacular.com/recipeImages/5-556x370...  Maindish
# ...                                                 ...       ...
# 1717  https://spoonacular.com/recipeImages/1995-556x...  Maindish
# 1718  https://spoonacular.com/recipeImages/1996-556x...   Starter
# 1719  https://spoonacular.com/recipeImages/1997-556x...  Maindish
# 1720  https://spoonacular.com/recipeImages/1998-556x...  Maindish
# 1721  https://spoonacular.com/recipeImages/127-556x3...   Starter
#
#                                             ingredients  calories  stars  \
# 0     anchovies,baking powder,egg,flour,sage leaves,...    384.09      3
# 1      anchovies,bread,garlic clove,olive oil,scallions     57.07      1
# 2     acini di pepe,almonds,anchovies,carrots,caulif...    942.08      4
# 3     anchovies,baby-back ribs,cooking oil,frying oi...   1697.23      3
# 4         bread,capers,salted anchovies,unsalted butter    112.75      5
# ...                                                 ...       ...    ...
# 1717  dried basil,dried thyme,ground cayenne pepper,...    466.57      3
# 1718  cherry tomatoes,chicken broth,fresh corn kerne...     24.02      4
# 1719  butter,chipotle chile in adobo,flour tortillas...    418.20      3
# 1720  brown rice,butter,carrots,chives,cider vinegar...    803.88      4
# 1721  cherry tomatoes,chillies,coconut,coconut,cocon...     77.49      5
#
#       popularity  userId  tfdbId  recipeId
# 0     150.437577       1       1      1915
# 1     139.082615       1       2      1916
# 2     107.376788       1       3      1918
# 3     112.312950       1       4      1919
# 4      43.926995       1       5      1920
# ...          ...     ...     ...       ...
# 1717   37.729059      14    1995      1480
# 1718   18.650748      14    1996      1481
# 1719   15.794946      14    1997      1482
# 1720   45.054936      14    1998      1483
# 1721   25.039383      14    1999      1484
#
# [1722 rows x 15 columns]

# %%
df['Recommend'] = np.nan
df['Recommend'] = df['Recommend'].astype('str')

# %%
df
# Out:
#         id                                             title  veryHealthy  \
# 0        1                         Fried Anchovies with Sage        False
# 1        2  Anchovies Appetizer With Breadcrumbs & Scallions        False
# 2        3                Carrots, Cauliflower And Anchovies         True
# 3        4  Bap Story Stir Fried Anchovies (Myulchi Bokkeum)         True
# 4        5                       Bread, Butter And Anchovies        False
# ...    ...                                               ...          ...
# 1717  1995                          Blackened Salmon Fillets        False
# 1718  1996                       Vegetable Stew With Halibut        False
# 1719  1997                 Snapper Tacos with Chipotle Cream        False
# 1720  1998                  Smoky Maple-glazed Salmon Supper         True
# 1721  1999                              spicy tomato mussels        False
#
#       veryPopular  readyInMinutes  \
# 0           False              45
# 1           False              15
# 2           False              45
# 3           False              45
# 4           False               3
# ...           ...             ...
# 1717        False              25
# 1718        False              37
# 1719        False              45
# 1720        False              45
# 1721        False              45
#
#                                    spoonacularSourceUrl  \
# 0     https://spoonacular.com/fried-anchovies-with-s...
# 1     https://spoonacular.com/anchovies-appetizer-wi...
# 2     https://spoonacular.com/carrots-cauliflower-an...
# 3     https://spoonacular.com/bap-story-stir-fried-a...
# 4     https://spoonacular.com/bread-butter-and-ancho...
# ...                                                 ...
# 1717  https://spoonacular.com/blackened-salmon-fille...
# 1718  https://spoonacular.com/vegetable-stew-with-ha...
# 1719  https://spoonacular.com/snapper-tacos-with-chi...
# 1720  https://spoonacular.com/smoky-maple-glazed-sal...
# 1721  https://spoonacular.com/spicy-tomato-mussels-1999
#
#                                                   image dishTypes  \
# 0     https://spoonacular.com/recipeImages/1-556x370...  Maindish
# 1     https://spoonacular.com/recipeImages/2-556x370...   Starter
# 2     https://spoonacular.com/recipeImages/3-556x370...  Maindish
# 3     https://spoonacular.com/recipeImages/4-556x370...  Maindish
# 4     https://spoonacular.com/recipeImages/5-556x370...  Maindish
# ...                                                 ...       ...
# 1717  https://spoonacular.com/recipeImages/1995-556x...  Maindish
# 1718  https://spoonacular.com/recipeImages/1996-556x...   Starter
# 1719  https://spoonacular.com/recipeImages/1997-556x...  Maindish
# 1720  https://spoonacular.com/recipeImages/1998-556x...  Maindish
# 1721  https://spoonacular.com/recipeImages/127-556x3...   Starter
#
#                                             ingredients  calories  stars  \
# 0     anchovies,baking powder,egg,flour,sage leaves,...    384.09      3
# 1      anchovies,bread,garlic clove,olive oil,scallions     57.07      1
# 2     acini di pepe,almonds,anchovies,carrots,caulif...    942.08      4
# 3     anchovies,baby-back ribs,cooking oil,frying oi...   1697.23      3
# 4         bread,capers,salted anchovies,unsalted butter    112.75      5
# ...                                                 ...       ...    ...
# 1717  dried basil,dried thyme,ground cayenne pepper,...    466.57      3
# 1718  cherry tomatoes,chicken broth,fresh corn kerne...     24.02      4
# 1719  butter,chipotle chile in adobo,flour tortillas...    418.20      3
# 1720  brown rice,butter,carrots,chives,cider vinegar...    803.88      4
# 1721  cherry tomatoes,chillies,coconut,coconut,cocon...     77.49      5
#
#       popularity  userId  tfdbId  recipeId Recommend
# 0     150.437577       1       1      1915       nan
# 1     139.082615       1       2      1916       nan
# 2     107.376788       1       3      1918       nan
# 3     112.312950       1       4      1919       nan
# 4      43.926995       1       5      1920       nan
# ...          ...     ...     ...       ...       ...
# 1717   37.729059      14    1995      1480       nan
# 1718   18.650748      14    1996      1481       nan
# 1719   15.794946      14    1997      1482       nan
# 1720   45.054936      14    1998      1483       nan
# 1721   25.039383      14    1999      1484       nan
#
# [1722 rows x 16 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1722 entries, 0 to 1721
# Data columns (total 16 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    1722 non-null   int64
#  1   title                 1722 non-null   object
#  2   veryHealthy           1722 non-null   bool
#  3   veryPopular           1722 non-null   bool
#  4   readyInMinutes        1722 non-null   int64
#  5   spoonacularSourceUrl  1722 non-null   object
#  6   image                 1718 non-null   object
#  7   dishTypes             1722 non-null   object
#  8   ingredients           1722 non-null   object
#  9   calories              1722 non-null   float64
#  10  stars                 1722 non-null   int64
#  11  popularity            1722 non-null   float64
#  12  userId                1722 non-null   int64
#  13  tfdbId                1722 non-null   int64
#  14  recipeId              1722 non-null   int64
#  15  Recommend             1722 non-null   object
# dtypes: bool(2), float64(2), int64(6), object(6)
# memory usage: 191.8+ KB

# %%
df["stars"] = df["stars"].astype("int64", errors='ignore')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1722 entries, 0 to 1721
# Data columns (total 16 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    1722 non-null   int64
#  1   title                 1722 non-null   object
#  2   veryHealthy           1722 non-null   bool
#  3   veryPopular           1722 non-null   bool
#  4   readyInMinutes        1722 non-null   int64
#  5   spoonacularSourceUrl  1722 non-null   object
#  6   image                 1718 non-null   object
#  7   dishTypes             1722 non-null   object
#  8   ingredients           1722 non-null   object
#  9   calories              1722 non-null   float64
#  10  stars                 1722 non-null   int64
#  11  popularity            1722 non-null   float64
#  12  userId                1722 non-null   int64
#  13  tfdbId                1722 non-null   int64
#  14  recipeId              1722 non-null   int64
#  15  Recommend             1722 non-null   object
# dtypes: bool(2), float64(2), int64(6), object(6)
# memory usage: 191.8+ KB

# %%
for i in df['veryHealthy'].index: 
  if(False==df['veryHealthy'][i] ): 
    df['Recommend'][i]='No' 
  elif(True==df['veryHealthy'][i] ): 
    df['Recommend'][i]='Yes'
# Out:
# C:\Users\sriha\AppData\Local\Temp/ipykernel_9132/2685834335.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Recommend'][i]='No'
# C:\Users\sriha\AppData\Local\Temp/ipykernel_9132/2685834335.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Recommend'][i]='Yes'

# %%
df
# Out:
#         id                                             title  veryHealthy  \
# 0        1                         Fried Anchovies with Sage        False
# 1        2  Anchovies Appetizer With Breadcrumbs & Scallions        False
# 2        3                Carrots, Cauliflower And Anchovies         True
# 3        4  Bap Story Stir Fried Anchovies (Myulchi Bokkeum)         True
# 4        5                       Bread, Butter And Anchovies        False
# ...    ...                                               ...          ...
# 1717  1995                          Blackened Salmon Fillets        False
# 1718  1996                       Vegetable Stew With Halibut        False
# 1719  1997                 Snapper Tacos with Chipotle Cream        False
# 1720  1998                  Smoky Maple-glazed Salmon Supper         True
# 1721  1999                              spicy tomato mussels        False
#
#       veryPopular  readyInMinutes  \
# 0           False              45
# 1           False              15
# 2           False              45
# 3           False              45
# 4           False               3
# ...           ...             ...
# 1717        False              25
# 1718        False              37
# 1719        False              45
# 1720        False              45
# 1721        False              45
#
#                                    spoonacularSourceUrl  \
# 0     https://spoonacular.com/fried-anchovies-with-s...
# 1     https://spoonacular.com/anchovies-appetizer-wi...
# 2     https://spoonacular.com/carrots-cauliflower-an...
# 3     https://spoonacular.com/bap-story-stir-fried-a...
# 4     https://spoonacular.com/bread-butter-and-ancho...
# ...                                                 ...
# 1717  https://spoonacular.com/blackened-salmon-fille...
# 1718  https://spoonacular.com/vegetable-stew-with-ha...
# 1719  https://spoonacular.com/snapper-tacos-with-chi...
# 1720  https://spoonacular.com/smoky-maple-glazed-sal...
# 1721  https://spoonacular.com/spicy-tomato-mussels-1999
#
#                                                   image dishTypes  \
# 0     https://spoonacular.com/recipeImages/1-556x370...  Maindish
# 1     https://spoonacular.com/recipeImages/2-556x370...   Starter
# 2     https://spoonacular.com/recipeImages/3-556x370...  Maindish
# 3     https://spoonacular.com/recipeImages/4-556x370...  Maindish
# 4     https://spoonacular.com/recipeImages/5-556x370...  Maindish
# ...                                                 ...       ...
# 1717  https://spoonacular.com/recipeImages/1995-556x...  Maindish
# 1718  https://spoonacular.com/recipeImages/1996-556x...   Starter
# 1719  https://spoonacular.com/recipeImages/1997-556x...  Maindish
# 1720  https://spoonacular.com/recipeImages/1998-556x...  Maindish
# 1721  https://spoonacular.com/recipeImages/127-556x3...   Starter
#
#                                             ingredients  calories  stars  \
# 0     anchovies,baking powder,egg,flour,sage leaves,...    384.09      3
# 1      anchovies,bread,garlic clove,olive oil,scallions     57.07      1
# 2     acini di pepe,almonds,anchovies,carrots,caulif...    942.08      4
# 3     anchovies,baby-back ribs,cooking oil,frying oi...   1697.23      3
# 4         bread,capers,salted anchovies,unsalted butter    112.75      5
# ...                                                 ...       ...    ...
# 1717  dried basil,dried thyme,ground cayenne pepper,...    466.57      3
# 1718  cherry tomatoes,chicken broth,fresh corn kerne...     24.02      4
# 1719  butter,chipotle chile in adobo,flour tortillas...    418.20      3
# 1720  brown rice,butter,carrots,chives,cider vinegar...    803.88      4
# 1721  cherry tomatoes,chillies,coconut,coconut,cocon...     77.49      5
#
#       popularity  userId  tfdbId  recipeId Recommend
# 0     150.437577       1       1      1915        No
# 1     139.082615       1       2      1916        No
# 2     107.376788       1       3      1918       Yes
# 3     112.312950       1       4      1919       Yes
# 4      43.926995       1       5      1920        No
# ...          ...     ...     ...       ...       ...
# 1717   37.729059      14    1995      1480        No
# 1718   18.650748      14    1996      1481        No
# 1719   15.794946      14    1997      1482        No
# 1720   45.054936      14    1998      1483       Yes
# 1721   25.039383      14    1999      1484        No
#
# [1722 rows x 16 columns]

# %%
df['stars'].dtype
# Out:
# dtype('int64')

# %%
df['calories'].dtype
# Out:
# dtype('float64')

# %%
df['stars'] = pd.to_numeric(df['stars'],errors = 'coerce')

# %%
df['stars'].dtype
# Out:
# dtype('int64')

# %%
print(df.iloc[:, [9, 10]])
# Out:
#       calories  stars
# 0       384.09      3
# 1        57.07      1
# 2       942.08      4
# 3      1697.23      3
# 4       112.75      5
# ...        ...    ...
# 1717    466.57      3
# 1718     24.02      4
# 1719    418.20      3
# 1720    803.88      4
# 1721     77.49      5
#
# [1722 rows x 2 columns]

# %%
print(df.iloc[:, 15])
# Out:
# 0        No
# 1        No
# 2       Yes
# 3       Yes
# 4        No
#        ...
# 1717     No
# 1718     No
# 1719     No
# 1720    Yes
# 1721     No
# Name: Recommend, Length: 1722, dtype: object

# %%
df['stars'] = df['stars'].replace(np.nan, 0)

# %%
df['calories'] = df['calories'].replace(np.nan, 0)

# %%
df['Recommend'] = df['Recommend'].replace(np.nan, 0)

# %%
x = df.iloc[:, [9, 10]].values  
y = df.iloc[:, 15].values

# %%
from sklearn.model_selection import train_test_split  
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.25, random_state = 5)

# %%
from sklearn.preprocessing import StandardScaler  
sc = StandardScaler()  
x_train = sc.fit_transform(x_train)  
x_test = sc.transform(x_test)

# %%
from sklearn.naive_bayes import GaussianNB  
classifier = GaussianNB()  
classifier.fit(x_train, y_train)
# Out:
# GaussianNB()

# %%
y_pred = classifier.predict(x_test)

# %%
from sklearn.metrics import accuracy_score

accuracy_score(y_test, y_pred)
# Out:
# 0.8004640371229699

# %%
from sklearn.metrics import confusion_matrix  
cm = confusion_matrix(y_test, y_pred)  

print(cm)
# Out:
# [[327   7]
#  [ 79  18]]

# %%
from sklearn.metrics import classification_report

print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#           No       0.81      0.98      0.88       334
#          Yes       0.72      0.19      0.30        97
#
#     accuracy                           0.80       431
#    macro avg       0.76      0.58      0.59       431
# weighted avg       0.79      0.80      0.75       431

# %%
TP = cm[0,0]
TN = cm[1,1]
FP = cm[0,1]
FN = cm[1,0]

# %%
classification_accuracy = (TP + TN) / float(TP + TN + FP + FN)

print('Classification accuracy : {0:0.4f}'.format(classification_accuracy))
# Out:
# Classification accuracy : 0.8005

# %%
# print classification error

classification_error = (FP + FN) / float(TP + TN + FP + FN)

print('Classification error : {0:0.4f}'.format(classification_error))
# Out:
# Classification error : 0.1995

# %%
# print precision score

precision = TP / float(TP + FP)


print('Precision : {0:0.4f}'.format(precision))
# Out:
# Precision : 0.9790

# %%
recall = TP / float(TP + FN)

print('Recall or Sensitivity : {0:0.4f}'.format(recall))
# Out:
# Recall or Sensitivity : 0.8054

# %%
true_positive_rate = TP / float(TP + FN)


print('True Positive Rate : {0:0.4f}'.format(true_positive_rate))
# Out:
# True Positive Rate : 0.8054

# %%
false_positive_rate = FP / float(FP + TN)


print('False Positive Rate : {0:0.4f}'.format(false_positive_rate))
# Out:
# False Positive Rate : 0.2800

# %%
specificity = TN / (TN + FP)

print('Specificity : {0:0.4f}'.format(specificity))
# Out:
# Specificity : 0.7200
